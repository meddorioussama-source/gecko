# %% [markdown]
# <center><h1> library main </h1></center>

# %% [markdown]
# ### 1. i dont know what should i write in the main page this will be writen by suggestions or somthing like this
# ### 2. there will be anthor location in the site one for each thing
# ### 3. if you want to share somthing send it to me directly on telegram or just use github
# ### 4. the sever name will change if we set it really to be a club
# ### 5. if you want to share use ipynb in other words jupyter notebook or collab.search google
# ### 6. if you dont know you can past pictures into jupyter
# ![Alt text](image1.png)
